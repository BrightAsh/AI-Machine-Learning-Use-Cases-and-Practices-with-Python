# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# !mkdir -p AI_Machine_Learning_Use_Cases_and_Practices_with_Python
# %cd AI_Machine_Learning_Use_Cases_and_Practices_with_Python
# !git clone https://github.com/BrightAsh/AI-Machine-Learning-Use-Cases-and-Practices-with-Python.git
# %cd AI-Machine-Learning-Use-Cases-and-Practices-with-Python
# Out:
# /content/drive/MyDrive
# /content/drive/MyDrive/lecture
# Cloning into 'AI-Machine-Learning-Use-Cases-and-Practices-with-Python'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/drive/MyDrive/lecture/AI-Machine-Learning-Use-Cases-and-Practices-with-Python

# %%
with open("test.py", "w") as f:
    f.write("print('Hello from Colab via Drive!')")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/AI_Machine_Learning_Use_Cases_and_Practices_with_Python/AI-Machine-Learning-Use-Cases-and-Practices-with-Python

# !git config --global user.email "busisi79@naver.com"
# !git config --global user.name "BrightAsh"

from google.colab import userdata

# 토큰 불러오기
token = userdata.get('token')

# 저장소 URL 구성
repo_url = f"https://{token}@github.com/BrightAsh/AI-Machine-Learning-Use-Cases-and-Practices-with-Python.git"

# Push 실행
# !git add .
# !git commit -m "test commit"
# !git push {repo_url}
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 308 bytes | 28.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/BrightAsh/AI-Machine-Learning-Use-Cases-and-Practices-with-Python.git
#    604604f..69c2680  main -> main

# %% [markdown]
# # 파일 이동

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import shutil
import requests

# 1. 현재 노트북 이름 가져오기
colab_url = "http://172.28.0.12:9000/api/sessions"
sessions = requests.get(colab_url).json()
notebook_name = sessions[0]["name"]   # 첫 번째 세션 기준

print("현재 노트북 이름:", notebook_name)

# 2. 경로 설정
src = f"/content/drive/MyDrive/Colab Notebooks/{notebook_name}"
dst_dir = "/content/drive/MyDrive/AI_Machine_Learning_Use_Cases_and_Practices_with_Python/AI-Machine-Learning-Use-Cases-and-Practices-with-Python"
dst = os.path.join(dst_dir, notebook_name)

# 3. 파일 이동
if os.path.exists(src):
    shutil.move(src, dst)
    print(f"✅ {notebook_name} 이동 완료 → {dst}")
else:
    print(f"⚠️ 파일을 찾을 수 없습니다: {src}")
